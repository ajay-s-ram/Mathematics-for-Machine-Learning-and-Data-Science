# %% [markdown]
# # Matrix Multiplication

# %%
import numpy as np

# %%
A = np.array([[4, 9, 9], [9, 1, 6], [9, 2, 3]])
print("Matrix A (3 by 3):\n", A)

B = np.array([[2, 2], [5, 7], [4, 4]])
print("Matrix B (3 by 2):\n", B)
# Out:
# Matrix A (3 by 3):
#  [[4 9 9]
#  [9 1 6]
#  [9 2 3]]
# Matrix B (3 by 2):
#  [[2 2]
#  [5 7]
#  [4 4]]

# %%
np.matmul(A, B)
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])

# %%
A @ B
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])

# %% [markdown]
# <a name='3'></a>
# ## Matrix Convention and Broadcasting

# %%
try:
    np.matmul(B, A)
except ValueError as err:
    print(err)
# Out:
# matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 2)

# %%
try:
    B @ A
except ValueError as err:
    print(err)
# Out:
# matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 2)

# %% [markdown]
# The number of the columns in the first matrix should match the number of the rows in the second matrix

# %%
x = np.array([1, -2, -5])
y = np.array([4, 3, -1])

print("Shape of vector x:", x.shape)
print("Number of dimensions of vector x:", x.ndim)
print("Shape of vector x, reshaped to a matrix:", x.reshape((3, 1)).shape)
print("Number of dimensions of vector x, reshaped to a matrix:", x.reshape((3, 1)).ndim)
# Out:
# Shape of vector x: (3,)
# Number of dimensions of vector x: 1
# Shape of vector x, reshaped to a matrix: (3, 1)
# Number of dimensions of vector x, reshaped to a matrix: 2

# %%
np.matmul(x,y)
# Out:
# np.int64(3)

# %% [markdown]
# vector $x$ was automatically transposed into the vector $1 \times 3$ and matrix multiplication $x^Ty$ was calculated.

# %%
try:
    np.matmul(x.reshape((3, 1)), y.reshape((3, 1)))
except ValueError as err:
    print(err)
# Out:
# matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 1)

# %% [markdown]
# `np.dot()` function also work for matrix multiplication

# %%
np.dot(A, B)
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])

# %%
A - 2
# Out:
# array([[ 2,  7,  7],
#        [ 7, -1,  4],
#        [ 7,  0,  1]])

# %% [markdown]
# Mathematically, subtraction of the $3 \times 3$ matrix $A$ and a scalar is not defined, but Python broadcasts the scalar, creating a $3 \times 3$ `np.array` and performing subtraction element by element.
